# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib notebook

# %%
img = mpimg.imread("/Users/beckermr/Downloads/DES0044-4040-coadd-gri.jpeg")
# Out:
# /Users/beckermr/miniconda3/envs/desy6/lib/python3.8/site-packages/PIL/Image.py:2918: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
sx = 0
sy = 0
ln = 10000
plt.imshow(img[sy:sy+ln, sx:sx+ln, :], origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">
