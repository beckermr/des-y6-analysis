# %%
import matplotlib.pyplot as plt

import fitsio
import numpy as np

# %%
im = fitsio.read(
    "sim_outputs_outpar/des-pizza-slices-y6-v14/DES0433-2332/"
    "DES0433-2332_r_des-pizza-slices-y6-v15_meds-pizza-slices-coadd-img.fits.fz"
)

# %%
im.shape
# Out:
# (10000, 10000)

# %%
fig, axs = plt.subplots(ncols=1, nrows=1, figsize=(10, 10))

axs.imshow(im.T[1200:1500, 1200:1500])
