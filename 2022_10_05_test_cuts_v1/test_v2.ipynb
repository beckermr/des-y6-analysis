# %%
import fitsio
import numpy as np
import proplot as pplt
from des_y6utils.mdet import make_mdet_cuts
import glob
import os

# %% [markdown]
# ### get total number

# %%
fnames = glob.glob(
    "/astro/u/beckermr/workarea/des-y6-analysis/2022_08_24_blind_and_test_final_cats/blinded_data/*.fits"
)

# %%
tot = 0
for i, fname in enumerate(fnames):
    d = fitsio.read(fname)
    tot += np.sum(make_mdet_cuts(d, 2, verbose=True) & (d["mdet_step"] == "noshear"))
    print("%d %e %e" % (
        i+1, tot/1e6, tot/(i+1)*len(fnames)/1e6
    ), flush=True)
    if i == 3:
        break
# Out:
# did cut psfrec_flags 673117
# did cut wmom_flags 673112
# did cut pgauss_T_flags 673112
# did cut pgauss_band_flux_flags_g 673112
# did cut pgauss_band_flux_flags_r 673112
# did cut pgauss_band_flux_flags_i 673112
# did cut pgauss_band_flux_flags_z 673112
# did cut mask_flags 673112
# did cut shear_bands 316248
# did cut pgauss_s2n 294675
# did mdet cuts 75825
# did mask cuts 61100
# 1 1.221600e-02 1.242245e+02
# did cut psfrec_flags 713575
# did cut wmom_flags 713575
# did cut pgauss_T_flags 713575
# did cut pgauss_band_flux_flags_g 713575
# did cut pgauss_band_flux_flags_r 713575
# did cut pgauss_band_flux_flags_i 713575
# did cut pgauss_band_flux_flags_z 713575
# did cut mask_flags 713575
# did cut shear_bands 328539
# did cut pgauss_s2n 306609
# did mdet cuts 74534
# did mask cuts 62968
# 2 2.483900e-02 1.262939e+02
# did cut psfrec_flags 745048
# did cut wmom_flags 745048
# did cut pgauss_T_flags 745048
# did cut pgauss_band_flux_flags_g 745048
# did cut pgauss_band_flux_flags_r 745048
# did cut pgauss_band_flux_flags_i 745048
# did cut pgauss_band_flux_flags_z 745048
# did cut mask_flags 745048
# did cut shear_bands 351838
# did cut pgauss_s2n 326674
# did mdet cuts 87649
# did mask cuts 73520
# 3 3.955700e-02 1.340850e+02
# did cut psfrec_flags 523323
# did cut wmom_flags 523323
# did cut pgauss_T_flags 523323
# did cut pgauss_band_flux_flags_g 523323
# did cut pgauss_band_flux_flags_r 523323
# did cut pgauss_band_flux_flags_i 523323
# did cut pgauss_band_flux_flags_z 523323
# did cut mask_flags 523323
# did cut shear_bands 243088
# did cut pgauss_s2n 218020
# did mdet cuts 60439
# did mask cuts 47534
# 4 4.905700e-02 1.247152e+02

# %%
ind = 10
d = fitsio.read(fnames[ind])
msk_mdet = make_mdet_cuts(d, 2, verbose=True) & (d["mdet_step"] == "noshear")
msk_msk = make_mdet_cuts(d, 1, verbose=True) & (d["mdet_step"] == "noshear")

fig, axs = pplt.subplots(figsize=(8, 8))
axs.plot(d["x"][msk_mdet], d["y"][msk_mdet], "k.", ms=1, label="latest")
axs.plot(d["x"][msk_msk], d["y"][msk_msk], "r.", ms=1, label="v1 mdet cuts")
axs.set_xlabel("x")
axs.set_ylabel("y")
axs.set_title(os.path.basename(fnames[ind]))
axs.legend(loc="t", frameon=False)
# Out:
# did cut psfrec_flags 727865
# did cut wmom_flags 727865
# did cut pgauss_T_flags 727865
# did cut pgauss_band_flux_flags_g 727865
# did cut pgauss_band_flux_flags_r 727865
# did cut pgauss_band_flux_flags_i 727865
# did cut pgauss_band_flux_flags_z 727865
# did cut mask_flags 727865
# did cut shear_bands 343611
# did cut pgauss_s2n 324500
# did mdet cuts 80994
# did mask cuts 70463
# did cut psfrec_flags 727865
# did cut wmom_flags 727865
# did cut pgauss_T_flags 727865
# did cut pgauss_band_flux_flags_g 727865
# did cut pgauss_band_flux_flags_r 727865
# did cut pgauss_band_flux_flags_i 727865
# did cut pgauss_band_flux_flags_z 727865
# did cut mask_flags 727865
# did cut shear_bands 343611
# did cut pgauss_s2n 324500
# did mdet cuts 80994
# did mask cuts 70469
# Figure(nrows=1, ncols=1, figwidth=8.0, figheight=8.0)

# %%
import glob

tot = 0
fnames = glob.glob(
    "/gpfs02/astro/desdata/esheldon/lensing/des-lensing/y6patches/patches/*.fits"
)
for i, fname in enumerate(fnames):
    d = fitsio.read(fname)
    tot += np.sum(make_mdet_cuts(d, 2) & (d["mdet_step"] == "noshear"))
    print("%d %e %e" % (
        i+1, tot/1e6, tot/(i+1)*200/1e6
    ), flush=True)

print("total:", tot)
# Out:
# 1 4.760780e-01 9.521560e+01
# 2 8.553880e-01 8.553880e+01
# 3 1.473982e+00 9.826547e+01
# 4 1.944068e+00 9.720340e+01
# 5 2.612151e+00 1.044860e+02
# 6 3.354950e+00 1.118317e+02
# 7 3.926280e+00 1.121794e+02
# 8 4.599122e+00 1.149780e+02
# 9 5.252429e+00 1.167206e+02
# 10 5.967284e+00 1.193457e+02
# 11 6.665735e+00 1.211952e+02
# 12 7.202805e+00 1.200468e+02
# 13 7.824543e+00 1.203776e+02
# 14 8.468245e+00 1.209749e+02
# 15 9.303831e+00 1.240511e+02
# 16 1.005680e+01 1.257100e+02
# 17 1.081203e+01 1.272004e+02
# 18 1.160983e+01 1.289981e+02
# 19 1.237654e+01 1.302794e+02
# 20 1.315487e+01 1.315487e+02
# 21 1.357100e+01 1.292476e+02
# 22 1.433704e+01 1.303367e+02
# 23 1.524138e+01 1.325337e+02
# 24 1.605972e+01 1.338310e+02
# 25 1.692956e+01 1.354365e+02
# 26 1.739175e+01 1.337827e+02
# 27 1.799155e+01 1.332708e+02
# 28 1.864721e+01 1.331944e+02
# 29 1.940443e+01 1.338237e+02
# 30 2.013118e+01 1.342079e+02
# 31 2.082571e+01 1.343594e+02
# 32 2.148552e+01 1.342845e+02
# 33 2.214793e+01 1.342298e+02
# 34 2.291996e+01 1.348233e+02
# 35 2.361526e+01 1.349443e+02
# 36 2.439515e+01 1.355286e+02
# 37 2.522750e+01 1.363648e+02
# 38 2.570866e+01 1.353087e+02
# 39 2.626361e+01 1.346852e+02
# 40 2.682307e+01 1.341154e+02
# 41 2.748428e+01 1.340697e+02
# 42 2.812758e+01 1.339409e+02
# 43 2.881425e+01 1.340198e+02
# 44 2.948158e+01 1.340072e+02
# 45 3.015990e+01 1.340440e+02
# 46 3.083003e+01 1.340436e+02
# 47 3.144811e+01 1.338217e+02
